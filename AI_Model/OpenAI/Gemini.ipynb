# %%
pip install google-generativeai

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyCNFa8zH4JxQe3m78_50Xug81A9WSISLvQ"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("전세사기와 관련된 판례 사례 두 가지 보여줘")
print(response.text)
# Out:
# 1. 대법원 2018도4566 판결 (2019. 6. 13.)
#
# 이 사건은 전세금을 받거나 전세권을 가지고 전세금을 받은 자가 전세금을 반환하거나 전세권을 상실하지 않고 전세금을 받은 이후 전세화된 부동산을 매도하여 이로 인해 전세차용인이 전세권을 상실하거나 전세금을 반환받지 못함으로써 재산상의 손해를 입은 경우 전세금 수령자나 전세권자가 손해배상책임을 지느냐는 문제와 전세차용인이 전세금을 수령한 자 및 전세권자를 상대로 각자 또는 병합하여 손해배상을 청구할 수 있는지 여부가 주된 쟁점이었습니다.
#
# 대법원은 전세차용인이 전세금을 수령한 자 및 전세권자를 상대로 각자 또는 병합하여 손해배상을 청구할 수 있다는 것을 인정하였습니다. 대법원은 전세금 수령자와 전세권자는 전세화된 부동산을 임대인으로부터 전세로 차용하고 전세금을 지급받은 자로서 전세권을 가지고 있으므로 전세차용인과 당사자성을 가지고 있고, 또한 전세차용인에게 부당한 전세금의 손실을 입히는 행위를 하지 말아야 할 의무를 지고 있다고 판시했습니다.
#
# 또한 대법원은 전세금 수령자나 전세권자가 전세화된 부동산을 매도하여 전세차용인이 전세권을 상실하거나 전세금을 반환받지 못함으로써 재산상의 손해를 입은 경우, 전세금 수령자나 전세권자는 전세차용인에게 손해배상책임을 지게 된다고 판시했습니다.
#
# 이 판결은 전세사기로 인해 전세차용인이 재산상의 손해를 입은 경우 전세금 수령자나 전세권자가 손해배상책임을 진다는 것을 명확히 하여 전세차용인의 권리를 보호하는 데 중요한 의미를 갖습니다.
#
# 2. 대법원 2017도12240 판결 (2018. 12. 20.)
#
# 이 사건은 전세금을 받거나 전세권을 가지고 전세금을 받은 자가 전세금을 반환하거나 전세권을 상실하지 않고 전세금을 받은 이후 전세화된 부동산을 매도하여 이로 인해 전세차용인이 전세권을 상실하거나 전세금을 반환받지 못함으로써 재산상의 손해를 입은 경우 전세금 수령자나 전세권자가 손해배상책임을 지느냐는 문제가 주된 쟁점이었습니다.
#
# ...

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyCNFa8zH4JxQe3m78_50Xug81A9WSISLvQ"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("전세사기 소송 절차 자세히 보여줘")
print(response.text)
# Out:
# 1. **소송 준비**
#
# * **증거 수집:** 피해자는 전세사기 사례를 증명하기 위해 관련 증거를 수집해야 합니다. 여기에는 계약서, 영수증, 전화기록, 이메일 등이 포함될 수 있습니다.
# * **변호사 선임:** 피해자는 전세사기를 전문으로 하는 변호사를 선임해야 합니다. 변호사는 피해자가 소송 절차를 이해하고 자신의 권리를 보호할 수 있도록 도와줄 것입니다.
#
# 2. **소송 제기**
#
# * **소장 제출:** 변호사는 피해자를 대신하여 소장을 제출합니다. 소장에는 전세사기 사건에 대한 세부 정보와 피해자가 청구하는 배상금액이 포함됩니다.
# * **소환장 수령:** 피고는 소장을 수령하고 소환장을 받게 됩니다. 소환장에는 피고가 소송에 대해 응답해야 하는 기간이 명시되어 있습니다.
#
# 3. **소송 절차**
#
# * **답변서 제출:** 피고는 소장을 수령한 후 일정 기간 내에 답변서를 제출해야 합니다. 답변서에는 피고가 소송에 대한 부인 또는 인정이 포함됩니다.
# * **증거 교환:** 피해자와 피고는 서로 증거를 교환합니다. 증거는 재판에서 사용될 수 있습니다.
# * **조정 회의:** 법원은 피해자와 피고가 합의에 도달할 수 있도록 조정 회의를 열 수 있습니다. 합의가 성립되면 소송은 종료됩니다.
#
# 4. **재판**
#
# * **재판일 설정:** 법원은 재판일을 설정합니다. 재판에서 피해자와 피고는 각자의 주장을 증거를 통해 입증해야 합니다.
# * **판결:** 법원은 피해자의 주장이 입증되었다고 판단하면 피해자에게 배상금을 판결할 것입니다.
#
# 5. **집행**
#
# * **판결 이행:** 피고는 판결에 따라 배상금을 피해자에게 지급해야 합니다. 피고가 판결을 이행하지 않으면 피해자는 재산 압류 등의 강제 집행 방법을 이용할 수 있습니다.
#
# 전세사기 소송은 복잡하고 시간이 많이 걸릴 수 있습니다. 그러나 변호사의 도움을 받으면 피해자는 자신의 권리를 보호하고 배상금을 받을 수 있습니다.

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyCNFa8zH4JxQe3m78_50Xug81A9WSISLvQ"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("소송 절차 자세히 보여줘")
print(response.text)
# Out:
# **1. 소장 제출**
#
# * 소제기인은 소송을 시작하기 위해 소장을 제출해야 합니다.
# * 소장은 소원, 소송 대상, 소송 이유를 포함해야 합니다.
# * 소장은 법원에 제출되며, 법원은 소장을 검토하여 소송을 허가할지 여부를 결정합니다.
#
# **2. 소환장 발부**
#
# * 법원이 소송을 허가하면 소환장을 발부합니다.
# * 소환장은 소송 대상에게 소송이 제기되었다는 사실을 통지하고, 소송 대상이 소송에 응해야 한다는 것을 명령합니다.
# * 소환장은 소송 대상에게 직접 전달되거나, 소송 대상의 주소지에 게시됩니다.
#
# **3. 응소장 제출**
#
# * 소송 대상은 소환장을 받은 후 일정 기간 내에 응소장을 제출해야 합니다.
# * 응소장은 소송에 대한 소송 대상의 주장을 포함해야 합니다.
# * 응소장은 법원에 제출되며, 법원은 응소장을 검토하여 소송을 계속 진행할지 여부를 결정합니다.
#
# **4. 증거 제출**
#
# * 소송이 계속 진행되면 소제기인과 소송 대상은 각자의 주장을 뒷받침하는 증거를 제출합니다.
# * 증거는 서류, 증인 증언, 전문가 의견 등 다양한 형태로 제출될 수 있습니다.
#
# **5. 공판**
#
# * 소제기인과 소송 대상이 증거를 제출한 후, 법원은 공판을 열 수 있습니다.
# * 공판은 법관이 소제기인과 소송 대상의 주장을 듣고, 증거를 검토하여 판결을 내리는 절차입니다.
#
# **6. 판결**
#
# * 법관은 공판을 마친 후, 판결을 내립니다.
# * 판결은 소제기인의 승소 또는 소송 대상의 승소 중 하나입니다.
# * 판결은 항소될 수 있으며, 항소가 이루어지면 상급 법원에서 재판이 진행됩니다.
#
# **7. 집행**
#
# * 법원의 판결이 확정되면, 소제기인은 판결을 집행할 수 있습니다.
# * 판결의 집행은 판결에 따라 소송 대상에게 돈을 지급하거나, 소송 대상의 재산을 압류하거나, 소송 대상을 투옥하는 등 다양한 방법으로 이루어질 수 있습니다.

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyCNFa8zH4JxQe3m78_50Xug81A9WSISLvQ"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("전세사기 당했는데 준비해야하는 서류 목록 보여줘")
print(response.text)
# Out:
# 1. 전세 계약서
# 2. 보증금 영수증
# 3. 전임 임대인의 신원증
# 4. 월세 영수증
# 5. 전기, 가스, 물 요금 영수증
# 6. 전세금 영수증
# 7. 보증금 지급일을 기록한 통장 사본
# 8. 통장 명세서
# 9. 전임 임대인의 전화번호와 주소
# 10. 전임 임대인이 계약을 위반했다는 증거(예: 문자 메시지, 이메일, 통화 기록 등)
# 11. 임대료 납부를 밝히는 전자 기록(인터넷 뱅킹, 모바일 뱅킹 등)
# 12. 전세금을 납부했음을 증명하는 다른 서류(예: 전임 임대인이 작성한 각서, 증인의 진술서 등)
# 13. 계약서 제목에 전세 계약이라고 명시되어 있는지 확인합니다.
# 14. 보증금 계약서 사본
# 15. 전임 임대인의 신원증 (주민등록증 사본 등)
# 16. 전임 임대인의 연락처 (전화번호, 주소 등)
# 17. 보증금 지급일을 기록한 통장 사본
# 18. 전세권 설정 등기에 관한 서류 (토지 등기부등본 사본 등)
# 19. 계약서 제목에 전세 계약이라고 명시되어 있는지 확인합니다.
# 20. 보증금 지급의 증거 (임대료 영수증, 은행 대금영수증 등)

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyCNFa8zH4JxQe3m78_50Xug81A9WSISLvQ"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("교통사고 당했는데 준비해야하는 서류 목록 보여줘")
print(response.text)
# Out:
# * **사고 보고서**
#     * 사고가 발생한 후 경찰이 작성하는 공식 보고서입니다.
#     * 교통사고의 날짜, 시간, 장소, 관련자 정보, 피해 상태 등이 기재되어 있습니다.
#     * 사고 보고서는 보험 청구, 법적 절차 등에 필요한 중요한 서류입니다.
#
#
# * **운전면허증**
#     * 사고 당시 운전하고 있던 사람의 운전면허증입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **자동차 등록증**
#     * 사고 당시 운전하던 자동차의 등록증입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **보험증**
#     * 사고 당시 운전하던 자동차의 보험증입니다.
#     * 보험 청구에 필요한 서류입니다.
#
#
# * **의료 기록**
#     * 사고로 인해 입은 부상을 치료한 의료 기록입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **실비 영수증**
#     * 사고로 인해 발생한 의료비, 수리비, 대여료 등의 실비 영수증입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **증인 진술서**
#     * 사고를 목격한 증인의 진술서입니다.
#     * 법적 절차에서 증거로 사용될 수 있습니다.
#
#
# * **사진**
#     * 사고 현장, 피해 차량, 부상 상태 등을 촬영한 사진입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **차량 수리 견적서**
#     * 사고로 인해 피해를 입은 차량을 수리하는 데 드는 비용을 추산한 견적서입니다.
#     * 보험 청구, 법적 절차 등에 필요한 서류입니다.
#
#
# * **보고서**
#     * 차량 수리 비용에 대한 세금 포함 견적서입니다.
#     * 보험 청구에 필요한 서류입니다.
#
#
# * **법률 자문**
# ...
